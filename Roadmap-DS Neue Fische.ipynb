# %% [markdown]
# ## WEEK 1
#
# Topic: Einführung
# - Klassen und Funktionen in Python
# - Numpy, Pandas, Matplotlib
# - Verteilungen mit scipy
# - Empirische Statistik zur Beschreibung von Daten
# - Einlesen von Daten mittels Pandas
# - iPython Notebooks
#
#
# ## WEEK 2
#
# Topic: Daten Analyse
# - Visualisierung mit Matplotlib
# - Verteilungsfunktionen helfen uns Daten zu beschreiben
# - Unsupervised learning: Clustering von Daten mittels K-Means und Gaussian Mixture Modellen
#
#
# ## WEEK 3
#
# Topic: Predictive Analysis
# - Einführung Vorhersageverfahren
# - Regression: Lineare Regression und K-Nearest Neighbors
# - Feature engineering
# - Fehlermaße: MSE, RSS, RSE, R^2
# - Datenbereinigung
# - Model Evaluierung
#
#
# ## WEEK 4
#
# Topic: Linear Models
# - Zusammenhang zwische linearen Modellen und Least Squares
# - Classification: Logistische Regression
# - Evaluierung durch AUC, MSE, LogLoss
# - Generalization
# - Programmieren mit einer IDE
# - Test-driven Development
#
#
# ## WEEK 5
#
# Topic: Prediction Models
# - Überblick über verschiedene Vorhersage-Modelle
# - Teamarbeit mit Git
# - Code Reviews / Pull-Requests
# - Overfitting / Regularization / Averaging
# - Dimensions Reduktion
#
#
# ## WEEK 6
#
# Topic: Machine Learning Frameworks
# - pyTorch: Linear model in pyTorch
# - Optimierung: Stochastic gradient descent
# - Optimierung: Minibatching
# - Back propagation
#
#
# ## WEEK 7
# Topic: Deep Learning
# - Multilayer Network
# - GPU computing
# - Training monitoring
#
#
# ## WEEK 8
# Topic: Large datasets "big data" & Cloud Computing
# - Einführung in Spark
# - SQL Interface
# - Data preparation, data cleaning
# - Distributed computing
#
#
# ## WEEK 9-12
# Topic: Gesellenstück
# - Github Projekt
# - Kaggle Challenge
# - Agile Working
